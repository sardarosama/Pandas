# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/AI/walmart.csv')
data
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    A          99  2011-12-09        895.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...

# %%
data.head()
# Out:
#    store type  department        date  weekly_sales  is_holiday  \
# 0      1    A           1  2010-02-05      24924.50       False
# 1      1    A           1  2010-03-05      21827.90       False
# 2      1    A           1  2010-04-02      57258.43       False
# 3      1    A           1  2010-05-07      17413.94       False
# 4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   store                 10774 non-null  int64
#  1   type                  10774 non-null  object
#  2   department            10774 non-null  int64
#  3   date                  10774 non-null  object
#  4   weekly_sales          10774 non-null  float64
#  5   is_holiday            10774 non-null  bool
#  6   temperature_c         10774 non-null  float64
#  7   fuel_price_usd_per_l  10774 non-null  float64
#  8   unemployment          10774 non-null  float64
# dtypes: bool(1), float64(4), int64(2), object(2)
# memory usage: 684.0+ KB

# %%
data.shape
# Out:
# (10774, 9)

# %%
data.describe()
# Out:
#               store    department   weekly_sales  temperature_c  \
# count  10774.000000  10774.000000   10774.000000   10774.000000
# mean      15.441897     45.218118   23843.950149      15.731978
# std       11.534511     29.867779   30220.387557       9.922446
# min        1.000000      1.000000   -1098.000000      -8.366667
# 25%        4.000000     20.000000    3867.115000       7.583333
# 50%       13.000000     40.000000   12049.065000      16.966667
# 75%       20.000000     72.000000   32349.850000      24.166667
# max       39.000000     99.000000  293966.050000      33.827778
#
#        fuel_price_usd_per_l  unemployment
# count          10774.000000  10774.000000
# mean               0.749746      8.082009
# std                0.059494      0.624355
# min                0.664129      3.879000
# 25%                0.708246      7.795000
# 50%                0.743381      8.099000
# 75%                0.781421      8.360000
# max                1.107674      9.765000

# %%
data.values
# Out:
# array([[1, 'A', 1, ..., 5.727777777777779, 0.6794508388787476, 8.106],
#        [1, 'A', 1, ..., 8.055555555555555, 0.693451964252221, 8.106],
#        [1, 'A', 1, ..., 16.81666666666667, 0.718284148876872, 7.808],
#        ...,
#        [39, 'A', 99, ..., 27.28888888888889, 0.911922354513778, 6.989],
#        [39, 'A', 99, ..., 25.64444444444444, 0.8601446078496121,
#         6.622999999999999],
#        [39, 'A', 99, ..., 22.25, 0.955510763695346, 6.228]], dtype=object)

# %%
data.columns
# Out:
# Index(['store', 'type', 'department', 'date', 'weekly_sales', 'is_holiday',
#        'temperature_c', 'fuel_price_usd_per_l', 'unemployment'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10774, step=1)

# %%
data.sort_values(by='weekly_sales', ascending= False)
# Out:
#       store type  department        date  weekly_sales  is_holiday  \
# 6201     14    A          92  2010-02-05     293966.05       False
# 4271     10    B          72  2010-02-05     232558.51       False
# 4281     10    B          72  2010-12-03     218559.54       False
# 6202     14    A          92  2010-03-05     214383.07       False
# 6237     14    A          95  2010-02-05     213042.66       False
# ...     ...  ...         ...         ...           ...         ...
# 517       1    A          47  2010-03-12       -698.00       False
# 4110     10    B          47  2010-03-05       -798.00       False
# 4115     10    B          47  2010-10-15       -798.00       False
# 1422      2    A          47  2010-10-15      -1098.00       False
# 1420      2    A          47  2010-07-30      -1098.00       False
#
#       temperature_c  fuel_price_usd_per_l  unemployment
# 6201      -2.605556              0.735455         8.992
# ...

# %%
data['weekly_sales']
# Out:
# 0        24924.50
# 1        21827.90
# 2        57258.43
# 3        17413.94
# 4        17558.09
#            ...
# 10769      895.00
# 10770      350.00
# 10771      450.00
# 10772        0.06
# 10773      915.00
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data['weekly_sales'] > 300
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 10769     True
# 10770     True
# 10771     True
# 10772    False
# 10773     True
# Name: weekly_sales, Length: 10774, dtype: bool

# %%
data[(data['weekly_sales'] > 20000) & (data['type']=='B' )]
# Out:
#       store type  department        date  weekly_sales  is_holiday  \
# 3593     10    B           1  2010-02-05      40212.84       False
# 3594     10    B           1  2010-03-05      36572.44       False
# 3595     10    B           1  2010-04-02     131853.01       False
# 3596     10    B           1  2010-05-07      29819.93       False
# 3597     10    B           1  2010-06-04      27739.80       False
# ...     ...  ...         ...         ...           ...         ...
# 4454     10    B          95  2010-09-03      81395.84       False
# 4455     10    B          95  2010-10-01      75483.41       False
# 4456     10    B          95  2010-11-05      66860.90       False
# 4457     10    B          95  2010-12-03      60655.66       False
# 4458     10    B          95  2011-01-07      67181.85       False
#
#       temperature_c  fuel_price_usd_per_l  unemployment
# 3593      12.411111              0.782478         9.765
# ...

# %%
store_data=data['store'].isin([2,3,4])
store_data
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10769    False
# 10770    False
# 10771    False
# 10772    False
# 10773    False
# Name: store, Length: 10774, dtype: bool

# %%
data['weekly_sales_in_K'] =  data['weekly_sales']/1000
data
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    A          99  2011-12-09        895.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment  weekly_sales_in_K
# ...

# %%
data['weekly_sales'].quantile(0.2)
# Out:
# 2673.75

# %%
def weekly_sale(weekkly_sales):
  return data['weekly_sales'].quantile(0.5)

data['weekly_sales'].agg(weekly_sale)
# Out:
# 0        12049.065
# 1        12049.065
# 2        12049.065
# 3        12049.065
# 4        12049.065
#            ...
# 10769    12049.065
# 10770    12049.065
# 10771    12049.065
# 10772    12049.065
# 10773    12049.065
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data['weekly_sales'].cumsum()
# Out:
# 0        2.492450e+04
# 1        4.675240e+04
# 2        1.040108e+05
# 3        1.214248e+05
# 4        1.389829e+05
#              ...
# 10769    2.568930e+08
# 10770    2.568934e+08
# 10771    2.568938e+08
# 10772    2.568938e+08
# 10773    2.568947e+08
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data['weekly_sales'].cummax()
# Out:
# 0         24924.50
# 1         24924.50
# 2         57258.43
# 3         57258.43
# 4         57258.43
#            ...
# 10769    293966.05
# 10770    293966.05
# 10771    293966.05
# 10772    293966.05
# 10773    293966.05
# Name: weekly_sales, Length: 10774, dtype: float64

# %%
data.drop_duplicates(subset='weekly_sales')
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10761     39    A          98  2010-12-03       8980.72       False
# 10762     39    A          98  2011-01-07       7666.71       False
# 10765     39    A          99  2010-09-24        167.00       False
# 10767     39    A          99  2011-08-19        622.00       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment  weekly_sales_in_K
# ...

# %%
data['weekly_sales'].value_counts()
# Out:
# 12.00        25
# 10.47        16
# 0.00         15
# 7.00         14
# 5.00         14
#              ..
# 112995.06     1
# 112630.91     1
# 115484.56     1
# 123356.64     1
# 915.00        1
# Name: weekly_sales, Length: 10353, dtype: int64

# %%
data['weekly_sales'].value_counts(normalize=True)
# Out:
# 12.00        0.002320
# 10.47        0.001485
# 0.00         0.001392
# 7.00         0.001299
# 5.00         0.001299
#                ...
# 112995.06    0.000093
# 112630.91    0.000093
# 115484.56    0.000093
# 123356.64    0.000093
# 915.00       0.000093
# Name: weekly_sales, Length: 10353, dtype: float64

# %%
data[data['type']=='B']['weekly_sales'].mean()
# Out:
# 25696.67837028825

# %%
data.groupby([data['type']=='B'])['weekly_sales'].mean()
# Out:
# type
# False    23674.667242
# True     25696.678370
# Name: weekly_sales, dtype: float64

# %%
data.groupby([data['type']=='B'])['weekly_sales'].agg([max,min,sum])
# Out:
#              max     min           sum
# type
# False  293966.05 -1098.0  2.337163e+08
# True   232558.51  -798.0  2.317840e+07

# %%
data.groupby([data['type']=='A'])['weekly_sales'].agg([max,min,sum])
# Out:
#              max     min           sum
# type
# False  232558.51  -798.0  2.317840e+07
# True   293966.05 -1098.0  2.337163e+08

# %%
data.pivot_table(values='weekly_sales', index='type', aggfunc=np.max,margins=True)
# Out:
#       weekly_sales
# type
# A        293966.05
# B        232558.51
# All      293966.05

# %%
data.set_index('weekly_sales')
# Out:
#               store type  department        date  is_holiday  temperature_c  \
# weekly_sales
# 24924.50          1    A           1  2010-02-05       False       5.727778
# 21827.90          1    A           1  2010-03-05       False       8.055556
# 57258.43          1    A           1  2010-04-02       False      16.816667
# 17413.94          1    A           1  2010-05-07       False      22.527778
# 17558.09          1    A           1  2010-06-04       False      27.050000
# ...             ...  ...         ...         ...         ...            ...
# 895.00           39    A          99  2011-12-09       False       9.644444
# 350.00           39    A          99  2012-02-03       False      15.938889
# 450.00           39    A          99  2012-06-08       False      27.288889
# 0.06             39    A          99  2012-07-13       False      25.644444
# 915.00           39    A          99  2012-10-05       False      22.250000
#
# ...

# %%
data.reset_index(drop=True)
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    A          99  2011-12-09        895.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment  weekly_sales_in_K
# ...

# %%
data.columns
# Out:
# Index(['store', 'type', 'department', 'date', 'weekly_sales', 'is_holiday',
#        'temperature_c', 'fuel_price_usd_per_l', 'unemployment',
#        'weekly_sales_in_K'],
#       dtype='object')

# %%
data.sort_index(level=['date','department'],ascending=[False])
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 10773     39    A          99  2012-10-05        915.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10769     39    A          99  2011-12-09        895.00       False
# ...      ...  ...         ...         ...           ...         ...
# 4          1    A           1  2010-06-04      17558.09       False
# 3          1    A           1  2010-05-07      17413.94       False
# 2          1    A           1  2010-04-02      57258.43       False
# 1          1    A           1  2010-03-05      21827.90       False
# 0          1    A           1  2010-02-05      24924.50       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment  weekly_sales_in_K
# ...

# %%
data.loc[:,'date':'weekly_sales']
# Out:
#              date  weekly_sales
# 0      2010-02-05      24924.50
# 1      2010-03-05      21827.90
# 2      2010-04-02      57258.43
# 3      2010-05-07      17413.94
# 4      2010-06-04      17558.09
# ...           ...           ...
# 10769  2011-12-09        895.00
# 10770  2012-02-03        350.00
# 10771  2012-06-08        450.00
# 10772  2012-07-13          0.06
# 10773  2012-10-05        915.00
#
# [10774 rows x 2 columns]

# %%
data.loc[:,['type','weekly_sales']]
# Out:
#       type  weekly_sales
# 0        A      24924.50
# 1        A      21827.90
# 2        A      57258.43
# 3        A      17413.94
# 4        A      17558.09
# ...    ...           ...
# 10769    A        895.00
# 10770    A        350.00
# 10771    A        450.00
# 10772    A          0.06
# 10773    A        915.00
#
# [10774 rows x 2 columns]

# %%
data.loc[:,::4]
# Out:
#        store  weekly_sales  unemployment
# 0          1      24924.50         8.106
# 1          1      21827.90         8.106
# 2          1      57258.43         7.808
# 3          1      17413.94         7.808
# 4          1      17558.09         7.808
# ...      ...           ...           ...
# 10769     39        895.00         7.716
# 10770     39        350.00         7.244
# 10771     39        450.00         6.989
# 10772     39          0.06         6.623
# 10773     39        915.00         6.228
#
# [10774 rows x 3 columns]

# %%
data.iloc[1:10,2:5]
# Out:
#    department        date  weekly_sales
# 1           1  2010-03-05      21827.90
# 2           1  2010-04-02      57258.43
# 3           1  2010-05-07      17413.94
# 4           1  2010-06-04      17558.09
# 5           1  2010-07-02      16333.14
# 6           1  2010-08-06      17508.41
# 7           1  2010-09-03      16241.78
# 8           1  2010-10-01      20094.19
# 9           1  2010-11-05      34238.88

# %%
data['weekly_sales'].hist(bins=5)

# %%
data.plot(x='department',y='weekly_sales', kind='line')

# %%
data.isna()
# Out:
#        store   type  department   date  weekly_sales  is_holiday  \
# 0      False  False       False  False         False       False
# 1      False  False       False  False         False       False
# 2      False  False       False  False         False       False
# 3      False  False       False  False         False       False
# 4      False  False       False  False         False       False
# ...      ...    ...         ...    ...           ...         ...
# 10769  False  False       False  False         False       False
# 10770  False  False       False  False         False       False
# 10771  False  False       False  False         False       False
# 10772  False  False       False  False         False       False
# 10773  False  False       False  False         False       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment  weekly_sales_in_K
# 0              False                 False         False              False
# ...

# %%
data.isna().any()
# Out:
# store                   False
# type                    False
# department              False
# date                    False
# weekly_sales            False
# is_holiday              False
# temperature_c           False
# fuel_price_usd_per_l    False
# unemployment            False
# weekly_sales_in_K       False
# dtype: bool

# %%
data.isna().sum()
# Out:
# store                   0
# type                    0
# department              0
# date                    0
# weekly_sales            0
# is_holiday              0
# temperature_c           0
# fuel_price_usd_per_l    0
# unemployment            0
# weekly_sales_in_K       0
# dtype: int64

# %%
data.fillna(0)
# Out:
#        store type  department        date  weekly_sales  is_holiday  \
# 0          1    A           1  2010-02-05      24924.50       False
# 1          1    A           1  2010-03-05      21827.90       False
# 2          1    A           1  2010-04-02      57258.43       False
# 3          1    A           1  2010-05-07      17413.94       False
# 4          1    A           1  2010-06-04      17558.09       False
# ...      ...  ...         ...         ...           ...         ...
# 10769     39    A          99  2011-12-09        895.00       False
# 10770     39    A          99  2012-02-03        350.00       False
# 10771     39    A          99  2012-06-08        450.00       False
# 10772     39    A          99  2012-07-13          0.06       False
# 10773     39    A          99  2012-10-05        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment  weekly_sales_in_K
# ...

# %% [markdown]
# Create  a data frame
